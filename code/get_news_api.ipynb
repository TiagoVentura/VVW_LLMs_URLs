# %%
#!/usr/bin/env python3
# coding: utf-8

# In[57]:

# news api 
import requests
from datetime import datetime
import pandas as pd
from datetime import date 
from datetime import datetime
import json
import requests
from bs4 import BeautifulSoup


# In[58]:


api_key = "b7cd9a15f6ba4979ab21c3d0317948c3"

print(api_key)
# In[59]:


# Function to scrape the main text from <p> tags of an article
def scrape_article_text(url):
    try:
        # Send a request to the URL
        response = requests.get(url,  timeout=5)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Parse the HTML content
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Find all the <p> tags and extract the text
            paragraphs = soup.find_all('p')
            text = ' '.join([para.get_text() for para in paragraphs])
            
            return text.strip()  # Return the cleaned text
        else:
            return f"Failed to retrieve article: {response.status_code}"
    
    except Exception as e:
        return f"Error occurred: {str(e)}"


# In[60]:


# Function to fetch top headlines in the United States
def get_top_headlines(country, base_path, api_key):
    
    # parameters
    url = 'https://newsapi.org/v2/top-headlines'
    params = {
            'country': 'us',  # for US headlines
            'apiKey': api_key,
            'pageSize': 1
        }
    
    # macros
    # creating the date object of today's date 
    todays_date = date.today()

    # time
    todays_time = datetime.now().strftime('%H-%M')

    # Send the request to the API
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        articles = data.get('articles', [])
    else:
        print(f"Error: {response.status_code} - {response.text}")

    # save
    filename = country + "_" + str(todays_date) + "_" + str(todays_time) + ".json"

    # add date
    [a.update({"date": str(todays_date)}) for a in articles]
    
    # add text of the article
    for article in articles:
        # scrape
        print("Downloading " + article["url"])
        article["content"] = scrape_article_text(article["url"])
    
    # Convert the dictionary to JSON and save it to the file
    with open(f'{base_path}/{filename}', "w") as json_file:
            json.dump(articles, json_file)
    
    print("saving" + f'{base_path}/{filename}')
    
    return articles        

# Call the function
get_top_headlines(country="US", base_path="/Users/tb186/dropbox/artigos/VVW_LLMs_urls/news_us", api_key=api_key)
# Out:
# b7cd9a15f6ba4979ab21c3d0317948c3
# Downloading https://apnews.com/article/trump-assassination-attempt-what-to-know-564c56e167c3cdc6c50f6a2e91db9a6c
# saving/Users/tb186/dropbox/artigos/VVW_LLMs_urls/news_us/US_2024-09-17_09-03.json
# [{'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'ADRIANA GOMEZ LICON',
#   'title': '5 things to know about the apparent assassination attempt on Trump at one of his golf courses - The Associated Press',
#   'description': 'Former President Donald Trump is safe following what the FBI says “appears to be an attempted assassination” in Florida after another attempt on his life at a rally in Pennsylvania. Local authorities say the U.S. Secret Service agents protecting Trump fired a…',
#   'url': 'https://apnews.com/article/trump-assassination-attempt-what-to-know-564c56e167c3cdc6c50f6a2e91db9a6c',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/9bb41e8/2147483647/strip/true/crop/3516x1978+0+185/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%
# 2                    {'id': None, 'name': 'Deadline'}
# 3   {'id': 'bleacher-report', 'name': 'Bleacher Re...
# 4   {'id': 'associated-press', 'name': 'Associated...
# 5   {'id': 'the-washington-post', 'name': 'The Was...
# 6                    {'id': None, 'name': 'BBC News'}
# 7              {'id': None, 'name': 'Foxweather.com'}
# 8                     {'id': None, 'name': '9to5Mac'}
# 9                  {'id': None, 'name': 'CBS Sports'}
# 10                   {'id': None, 'name': 'Page Six'}
# 11                  {'id': None, 'name': '[Removed]'}
# 12  {'id': 'al-jazeera-english', 'name': 'Al Jazee...
# 13              {'id': None, 'name': 'Seeking Alpha'}
# 14                        {'id': None, 'name': 'NPR'}
# 15                       {'id': 'cnn', 'name': 'CNN'}
# 16           {'id': 'usa-today', 'name': 'USA Today'}
# 17             {'id': 'cbs-news', 'name': 'CBS News'}
# 18                    {'id': None, 'name': 'YouTube'}
# 19             {'id': 'nbc-news', 'name': 'NBC News'}
# 20                 {'id': None, 'name': 'Gbnews.com'}
# 21                {'id': None, 'name': 'MarketWatch'}
# 22             {'id': 'cbs-news', 'name': 'CBS News'}
# 23                {'id': None, 'name': 'POLITICO.eu'}
# 24          {'id': None, 'name': 'The Seattle Times'}
# 25           {'id': 'bloomberg', 'name': 'Bloomberg'}
# 26                  {'id': None, 'name': 'Ipsos.com'}
# 27                {'id': None, 'name': 'Motley Fool'}
# 28        {'id': None, 'name': 'Yahoo Entertainment'}
# 29             {'id': 'nbc-news', 'name': 'NBC News'}
# 30             {'id': 'nbc-news', 'name': 'NBC News'}
# 31                     {'id': None, 'name': 'Forbes'}
# 32                  {'id': None, 'name': '[Removed]'}
# 33                  {'id': None, 'name': '[Removed]'}
# 34             {'id': 'nbc-news', 'name': 'NBC News'}
#
#                                                author  \
# 0                                  Yahoo Sports Staff
# 1   ALANNA DURKIN RICHER, COLLEEN LONG, ERIC TUCKE...
# 2                                         Ted Johnson
# 3                                  Nicholas Nathanson
# 4                                        Dave Skretta
# 5                                          Ben Brasch
# 6                                                None
# 7                                       Brian Donegan
# 8                                   Michael Burkhardt
# 9
# 10                                      Tamantha Ryan
# 11                                               None
# 12                                   Al Jazeera Staff
# 13                                        Rob Johnson
# 14
# 15                                      Radina Gigova
# 16                                 Adrianna Rodriguez
# 17                                  Emily Mae Czachor
# 18                                               None
# 19                         Erik Ortiz, Angela Dallman
# 20                                     James Saunders
# 21                                    Joseph Adinolfi
# 22                                         Jon LaPook
# 23                                    POLITICO Europe
# 24                                  Lauren Rosenblatt
# 25                                        Mark Gurman
# 26                                    Ipsos in Canada
# 27                                    The Motley Fool
# 28                                        Denise Chow
# 29                  Kristen Welker, Alexandra Marquez
# 30                                           NBC News
# 31                                        Ewan Spence
# 32                                               None
# 33                                               None
# 34                              Berkeley Lovelace Jr.
#
#                                                 title  \
# 0   Bears vs. Texans Sunday Night Football live up...
# 1   Trump was the subject of an apparent assassina...
# 2   Emmy Presenter Candice Bergen Compares JD Vanc...
# 3   NFL Highlights 2024: Live Tracking Top Plays, ...
# 4   Butker hits a 51-yard winner for KC after pena...
# 5   Death toll rises in European floods, authoriti...
# 6   Keir Starmer defends Sue Gray after reports of...
# 7   Tropical Storm Warning issued for North Caroli...
# 8   Kuo: iPhone 16 Pro demand lower than expected,...
# 9   Saints' win over Cowboys ends with final score...
# 10  Jane's Addiction cancels upcoming show, issues...
# 11                                          [Removed]
# 12  Trump’s VP pick JD Vance defends spreading fal...
# 13  Stock moves reflect downgrade for US economic ...
# 14  Trump says 'I hate Taylor Swift' after pop sta...
# 15  Russian strike hits apartment block in Ukraine...
# 16  New mammogram guidelines from FDA shift what p...
# 17  Royal family shares birthday messages for Prin...
# 18  Space X crew return to Earth following first c...
# 19  Bryan Kohberger moved to Boise ahead of Idaho ...
# 20  Asteroid warning issued by Nasa as meteor trav...
# 21  Fed interest-rate cuts could boost stocks, or ...
# 22  Experts warn against vaccine skepticism - CBS ...
# 23  Venezuela arrests US, EU citizens over alleged...
# 24  How long Boeing Machinists’ strike could last ...
# 25  Apple’s New Hearing Aid and Health Upgrades Sa...
# 26  Majority of Americans say Harris won the debat...
# 27  The Smartest Dividend Stocks to Buy With $500 ...
# 28  'Supermoon eclipse' will be visible across Nor...
# 29  Trump allies worry his ties to far-right activ...
# 30  Starliner crew speaks out on their new eight-m...
# 31  Apple Forced Into Drastic iPhone 16 Pro Downgr...
# 32                                          [Removed]
# 33                                          [Removed]
# 34  CDC says close contact of Missouri bird flu pa...
#
#                                           description  \
# 0   Both Buffalo and Miami were able to pick up wi...
# 1   The FBI says Donald Trump was the target of “w...
# 2   Bergen, a presenter, compared Vance's "childle...
# 3   Week 1 of the NFL season was not what fans lik...
# 4   Harrison Butker kicked a 51-yard field goal as...
# 5   At least seven people have died — five in Roma...
# 6   The prime minister's chief of staff has been t...
# 7   Potential Tropical Cyclone Eight formed off th...
# 8   According to new pre-order analysis from Ming ...
# 9          Ladies and gentlemen, we have a scorigami!
# 10  “We want to extend a heartfelt apology to our ...
# 11                                          [Removed]
# 12  Top US Republican politicians continue to repe...
# 13  Equity rotations recently are reflecting a dow...
# 14  The Republican presidential nominee directed h...
# 15  A Russian strike on an apartment block in the ...
# 16  An FDA ruling went into effect this week requi...
# 17  The British Royal Family, including Prince Wil...
# 18  Enjoy the videos and music you love, upload or...
# 19  Bryan Kohberger, the man accused in the murder...
# 20  A skyscraper-sized asteroid is set to narrowly...
# 21  Whether or not the central bank can avert a re...
# 22  Thanks to vaccinations, measles was declared e...
# 23                                               None
# 24  While Machinists strikes aren’t new for Boeing...
# 25  Apple’s new AirPods hearing-aid feature and ot...
# 26                                               None
# 27                                               None
# 28  Moon lovers have a reason to celebrate this week.
# 29  Donald Trump allies are worried that the forme...
# 30  Starliner astronauts Suni Williams and Butch W...
# 31  Apple is removing a key piece of software from...
# 32                                          [Removed]
# 33                                          [Removed]
# 34  In new flu report, the CDC said a close contac...
#
#                                                   url  \
# 0   https://sports.yahoo.com/live/bears-vs-texans-...
# 1   https://apnews.com/article/trump-shooting-guns...
